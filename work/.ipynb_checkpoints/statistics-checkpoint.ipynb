# %% [markdown]
# ## データ準備

# %%
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['tip_rate'] = df['tip'] / df['total_bill']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_rate
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]

# %%
#もうちょっと俯瞰してデータがどうなのか見たい
# →ヒストグラム、棒グラフ

# %% [markdown]
# ## 分布の描画

# %%
sns.displot(df['tip'],kde=False)

# %%
sns.catplot(x='time',data=df, kind='count')

# %% [markdown]
# ## 平均値

# %%
np.mean(df['tip_rate'])
# Out:
# 0.16080258172250478

# %%
df['tip_rate'].mean()
# Out:
# 0.16080258172250478

# %%
df.groupby('sex').mean()['tip_rate']
# Out:
# sex
# Male      0.157651
# Female    0.166491
# Name: tip_rate, dtype: float64

# %%
sns.barplot(x='sex',y='tip_rate',data=df,ci=None)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip_rate'>

# %% [markdown]
# ## 中央値

# %%
np.median(df['tip_rate'])
# Out:
# 0.15476977125802577

# %%
df['tip_rate']
# Out:
# 0      0.059447
# 1      0.160542
# 2      0.166587
# 3      0.139780
# 4      0.146808
#          ...
# 239    0.203927
# 240    0.073584
# 241    0.088222
# 242    0.098204
# 243    0.159744
# Name: tip_rate, Length: 244, dtype: float64

# %%
#中央値と平均値の値が違う
#　→外れ値が原因

# %%
sns.displot(df['tip_rate'],kde=False)

# %%
df['tip_rate'].median()
# Out:
# 0.15476977125802577

# %%
df['tip_rate'].mean()
# Out:
# 0.16080258172250478

# %%
df.groupby('sex').median()
# Out:
#         total_bill   tip  size  tip_rate
# sex
# Male         18.35  3.00     2  0.153492
# Female       16.40  2.75     2  0.155581

# %%
sns.barplot(x='sex',y='tip_rate',data=df,estimator=np.median,ci=None)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip_rate'>

# %%
df.sort_values('tip_rate',ascending=False)
# Out:
#      total_bill   tip     sex smoker  day    time  size  tip_rate
# 172        7.25  5.15    Male    Yes  Sun  Dinner     2  0.710345
# 178        9.60  4.00  Female    Yes  Sun  Dinner     2  0.416667
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1  0.325733
# 232       11.61  3.39    Male     No  Sat  Dinner     2  0.291990
# 183       23.17  6.50    Male    Yes  Sun  Dinner     4  0.280535
# ..          ...   ...     ...    ...  ...     ...   ...       ...
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5  0.065660
# 0         16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 57        26.41  1.50  Female     No  Sat  Dinner     2  0.056797
# 102       44.30  2.50  Female    Yes  Sat  Dinner     3  0.056433
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2  0.035638
#
# [244 rows x 8 columns]

# %% [markdown]
# ## 最頻値

# %%
mode,count=stats.mode(df)

# %%
print(mode)
print(count)
# Out:
# [[13.42 2.0 'Male' 'No' 'Sat' 'Dinner' 2 0.1448225923244026]]
# [[  3  33 157 151  87 176 156   2]]

# %%
df['size'].mode()
# Out:
# 0    2
# dtype: int64

# %% [markdown]
# ## 範囲

# %%
np.min(df['tip'])
# Out:
# 1.0

# %%
df['tip'].min()
# Out:
# 1.0

# %%
df.groupby('sex').min()
# Out:
#         total_bill  tip  size  tip_rate
# sex
# Male          7.25  1.0     1  0.035638
# Female        3.07  1.0     1  0.056433

# %%
df.groupby('sex').max()
# Out:
#         total_bill   tip  size  tip_rate
# sex
# Male         50.81  10.0     6  0.710345
# Female       44.30   6.5     6  0.416667

# %% [markdown]
# ## 四分位数

# %% [markdown]
# データを並べて4分割した時の25%,50%,75%  外れ値に強い

# %% [markdown]
# Q_3 - Q_1:四分位範囲(IQR)

# %% [markdown]
# (Q_3 - Q_1)/2 : 四分位偏差(QD)

# %%
np.quantile(df['tip_rate'],[0.25,0.5,0.75])
# Out:
# array([0.12912736, 0.15476977, 0.19147549])

# %%
df['tip_rate'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    0.129127
# 0.50    0.154770
# 0.75    0.191475
# Name: tip_rate, dtype: float64

# %%
stats.iqr(df['tip_rate'])  ##iqr
# Out:
# 0.06234812458689151

# %%
stats.iqr(df['tip_rate'])/2.  ##idr
# Out:
# 0.031174062293445756

# %% [markdown]
# ### 箱ひげ図

# %%
plt.boxplot(df['tip_rate'])
plt.show()

# %%
sns.boxplot(x='sex',y='tip_rate',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip_rate'>

# %% [markdown]
# ## 平均偏差
# 　・平均(もしくは中央値)からの偏差の絶対値の平均
#
# 　・絶対値が扱いにくい

# %% [markdown]
# ### →絶対値は扱いにくいので二乗する

# %% [markdown]
# ## 分散(variance)

# %% [markdown]
# ・平均からの偏差の**2乗**の平均
#
# ・通常標本の分散はs<sup>2</sup>、母集団の分散はσ<sup>2</sup>で表す

# %% [markdown]
# ### 　→二乗すると尺度がズレるので平方根をとる

# %% [markdown]
# ## 標準偏差(standard deviation)

# %% [markdown]
# ・平均からの偏差の2乗の平均**の平方根**(**分散の平方根**)
#
# ・通常標本の標準偏差はs,母集団の標準偏差はσで表す

# %% [markdown]
# ## 分散と標準偏差
#
# <u>分散を求める</u>
#
# ・np.var()
#
# <u>標準偏差を求める</u>
#
# ・np.std()

# %% [markdown]
# ## 分散

# %%
np.var(df['tip'])
# Out:
# 1.9066085124966428

# %% [markdown]
# ## 標準偏差

# %%
np.std(df['tip'])
# Out:
# 1.3807999538298958

# %% [markdown]
# ## 共分散(covariance)

# %% [markdown]
# ・2変数間の記述統計

# %% [markdown]
# $$
# s_{xy} = \sum_{i=1}^{n} (x_i - \overline{x})(y_i - \overline{y})
# $$

# %% [markdown]
# ## 共分散行列(covariance matrix)
#
# ・複数の変数間の分散と共分散を行列にしたもの
#
# ・変数が多くなると行列で捉えた方が便利
#
# ![スクリーンショット 2024-06-30 15.07.58.png](attachment:bf3ddea6-2e5d-45ea-862e-38d4f50f487d.png)

# %% [markdown]
# ## 共分散

# %%
np.cov(df['total_bill'],df['tip'],bias=True)
# Out:
# array([[78.92813149,  8.28938892],
#        [ 8.28938892,  1.90660851]])

# %%
x = np.stack([df['total_bill'],df['tip'],df['size']],axis=0)
np.cov(x,bias=True)
# Out:
# array([[78.92813149,  8.28938892,  5.04522121],
#        [ 8.28938892,  1.90660851,  0.64126747],
#        [ 5.04522121,  0.64126747,  0.9008835 ]])

# %% [markdown]
# **尺度が違うので**必ずしも相関を比べることはできない！

# %% [markdown]
# ### →標準化する必要がある(**相関係数**)

# %% [markdown]
# ## 相関係数
#
# ・共分散を標準化したのが相関係数
#
# ・共分散の取りうる値（最小値〜最大値）を計算し、-1~1の範囲にすることを考える
#
# ![スクリーンショット 2024-06-30 15.37.21.png](attachment:c3955fac-647b-47a8-8e9b-08f4feb84c95.png)

# %% [markdown]
# ## 相関行列
#
# ・複数の変数間の相関係数を行列にしたもの
#
# ・対角要素は1になる
#
# ![スクリーンショット 2024-06-30 15.45.00.png](attachment:e993d276-66e9-4b42-ae7c-917342366cb1.png)

# %% [markdown]
# ## 相関係数(correlation coefficient)
#
# <u>相関係数を求める</u>
#
#  ・np.corrcoef(xarray,yarray)
#
#  ・np.corrcoef(array)
#
#  ・df.corr()
#
# <u>相関行列を描画する</u>
#
#  ・sns.heatmap(df.corr())

# %%
np.corrcoef(df['total_bill'],df['tip'])
# Out:
# array([[1.        , 0.67573411],
#        [0.67573411, 1.        ]])

# %%
x = np.stack([df['total_bill'],df['tip'],df['size']],axis=0)
np.corrcoef(x)
# Out:
# array([[1.        , 0.67573411, 0.59831513],
#        [0.67573411, 1.        , 0.48929878],
#        [0.59831513, 0.48929878, 1.        ]])

# %% [markdown]
# | Pair             | Value  |
# |------------------|--------|
# | total_bill - tip | 0.6757 |
# | total_bill - size| 0.5983 |
# | tip - size       | 0.4893 |

# %%
df.corr()
# Out:
#             total_bill       tip      size  tip_rate
# total_bill    1.000000  0.675734  0.598315 -0.338624
# tip           0.675734  1.000000  0.489299  0.342370
# size          0.598315  0.489299  1.000000 -0.142860
# tip_rate     -0.338624  0.342370 -0.142860  1.000000

# %%
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 連関(association)
#
# ・カテゴリ変数間の相関関係
#
# ・分割表(contingency table)を用いて計算する
#
# ・分割表内の数字を観測度数(observed frequency)という
#
# ![スクリーンショット 2024-06-30 16.14.09.png](attachment:0d282967-8942-481c-b9ae-481f8ceb11b8.png)

# %% [markdown]
#
#
#
#
#
# ## 期待度数(expected frequencies)
#
# ・連関が無いと想定した場合の度数
#
# ![スクリーンショット 2024-06-30 16.20.11.png](attachment:3c584690-67f9-4160-aa1f-c7fc5d000f47.png)

# %% [markdown]
# 期待度数・・・**比率が同じになるはず**

# %% [markdown]
# ## カイ二乗（$\chi^2$：chi squared）
#
# ・観測度数が期待度数からどれくらい離れているかを計算した値
#
# ・{（観測度数ー期待度数）$^2$/期待度数}の総和
#
# $$
# \chi^2 = \sum_{i=1}^{a} \sum_{j=1}^{b} \frac{(n_{ij} - e_{ij})^2}{e_{ij}}
# $$

# %% [markdown]
# ![スクリーンショット 2024-06-30 17.34.07.png](attachment:0c9d3cd0-6655-4331-80c1-78616dc92f1a.png)

# %% [markdown]
# #### **共分散と同じで、標準化されてない**

# %% [markdown]
# ## 連関(association)

# %% [markdown]
# <u>分割表を求める</u>
#
# ・pd.crosstab(xarray,yarray)
#
# <u>$\chi^2$と期待度数を求める</u>
#
# ・stats.chi2_contingency(cont_table,correction=Fasle)
#
# 第一戻り値：$\chi^2$
#
# 第四戻り値：期待度数の分割表

# %%
pd.crosstab(df['sex'],df['time'])
# Out:
# time    Lunch  Dinner
# sex
# Male       33     124
# Female     35      52

# %%
cont_table = pd.crosstab(df['sex'],df['time'])
stats.chi2_contingency(cont_table,correction=False)
# Out:
# (10.277251918677742,
#  0.0013468039268008766,
#  1,
#  array([[ 43.75409836, 113.24590164],
#         [ 24.24590164,  62.75409836]]))

# %% [markdown]
# <style>
#   table {
#     width: 100%;
#     border-collapse: collapse;
#     text-align: center;
#   }
#   th, td {
#     border: 1px solid black;
#     padding: 8px;
#     text-align: center;
#   }
#   pre {
#     text-align: left; /* 配列のフォーマットを保持するために左揃え */
#     display: inline-block;
#   }
# </style>
#
# <table>
#   <tr>
#     <th>Pair</th>
#     <th>Value</th>
#   </tr>
#   <tr>
#     <td>\(\chi^2\)</td>
#     <td>10.277251918677742</td>
#   </tr>
#   <tr>
#     <td>期待度数</td>
#     <td>
#       <pre>
# array([[ 43.75409836, 113.24590164],
#        [ 24.24590164,  62.75409836]])
#       </pre>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## クラメールの連関係数
#
# ・連関の強さを表す指標
#
# ・$\chi^2$値を0〜1に標準化した値
#
# $$
# V = \sqrt{\frac{\chi^2}{( \min(a, b) - 1) N}}
# $$
#
# 　　　　　　　　　　　　　　　　　　　　　　　　　※min(a,b)は、行数a,列数bのうちの小さい方

# %%
def cramers_v(xarray, yarray):
    cont_table = pd.crosstab(xarray,yarray)
    chi_2 = stats.chi2_contingency(cont_table,correction=False)[0]
    xlen = len(xarray.unique())
    ylen = len(yarray.unique())
    smaller = min(xlen,ylen)
    total_sum = cont_table.values.sum()
    v_2 = chi_2 / ((smaller - 1) * total_sum)
    return np.sqrt(v_2)

# %%
cramers_v(df['sex'],df['time'])
# Out:
# 0.20523129613344476

# %% [markdown]
# ## 確率(probability)とは
#
# ・ある試行試行を同じ条件で何度も繰り返した時にある事象が起こる相対頻度の極限

# %% [markdown]
# ## 確率変数(random variable)
#
# ・値が確率的に変動する変数
#
# ・通常Xで表す
#
# ・それぞれの値に確率P(X)が対応している

# %% [markdown]
# ## 確率分布(probability distribution)
#
# ・確率がどのように分布しているのかを表したもの
#
# ・確率変数は、確率分布から生成された値と考えるとわかりやすい
#
# ![スクリーンショット 2024-06-30 19.53.46.png](attachment:38ab26d4-8bb6-4b05-b1d5-bbdf6269f12f.png)

# %% [markdown]
# <u>確率分布</u>
#
# ・stats.<確率分布>.<メソッド>
#
# <u>一様分布からランダムにデータを生成する</u>
#
# ・stats.randint.rvs(low,high)　　　　(lowからhigh-1までのランダムな整数を生成)
#
# ・stats.uniform.rvs(loc,scale)　　　　(locからloc+scaleまでのランダムな値を生成)

# %%
# random variates(rvs): 確率変量
stats.randint.rvs(1,7)
# Out:
# 5

# %%
stats.uniform.mean(0,1)
# Out:
# 0.5

# %% [markdown]
# ### ↑離散型確率変数、連続型確率変数
#
# ・離散型確率分布
#
#
# 　関数f(x):確率質量関数(PMF:Probability Mass Function)　(fx(x) = P(X = x))
#
#
#
# ・連続型確率分布
#
#
# 　関数fx(x):確率密度関数(PDF:Probabiliry Density Function)

# %% [markdown]
# ## 確率分布の描画

# %%
def simple_func(x):
    return 2*x + 3

# %%
simple_func(10)
# Out:
# 23

# %%
x = np.linspace(-3, 3, 100)
y = simple_func(x)

# %%
plt.plot(x,y)

# %%
x = np.arange(1, 7)
y = stats.randint(1, 7).pmf(x)
plt.plot(x,y, 'o')
plt.vlines(x, 0, y)

# %%
x = np.linspace(-2, 2, 100)
y = stats.uniform(0, 1).pdf(x)
plt.plot(x, y)

# %% [markdown]
# ## 確率密度と確率
#
# ・確率密度関数が描く面積が確率になる
#
# ・確率密度関数が描く全面積は1になる![スクリーンショット 2024-06-30 20.41.15.png](attachment:aa2ccfb3-90d6-4f9b-b224-cdf629e252a3.png)

# %% [markdown]
# ## 累積分布関数(CDF:Cumulative Distribution Function)
#
# ・確率密度関数を負の無限大からある値(x)まで確率を積み上げた値を返す関数

# %% [markdown]
# ## 累積分布関数(CDF)の描画
#
# <u>正規分布の確率密度関数(PDF)と累積分布関数(CDF)を描画する</u>
#
# ・PDF:stats.norm.pdf(x)
#
# ・CDF:stats.norm.cdf(x)
#
# <u>右側の面積(1-累積分布関数(CDF))を求める</u>
#
# ・SF(Survival Function):stats.norm.sf(x)

# %%
x = np.linspace(-3, 3, 100)
y = stats.norm.pdf(x)
plt.plot(x,y)

# %%
y = stats.norm.cdf(x)
plt.plot(x,y)

# %%
y = stats.norm.sf(x)
plt.plot(x,y)

# %% [markdown]
# ## 正規分布(normal distribution)
#
# ・最もよく使われる分布
#
# ・自然界の多くで見られる分布(身長、誤差)
#
# ・統計学の理論でもよく出てくる分布
#
# ・平均μと分散$σ^2$で形状が決まる$N(μ,σ^2)$
#
# 正規分布の式は以下の通りです：
#
# 正規分布の式は以下の通りです：
#
# $$
# \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left(-\frac{(x - \mu)^2}{2\sigma^2}\right)
# $$
#
# ![スクリーンショット 2024-06-30 21.09.15.png](attachment:0f7c6b25-ac1a-40a6-892e-203f731bce6d.png)

# %%
x = np.linspace(-5, 15, 100)
y = stats.norm(loc=10, scale=3).pdf(x)
y2 = stats.norm(loc=8, scale=3).pdf(x)
y3 = stats.norm(loc=8, scale=1).pdf(x)
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
y = stats.norm.pdf(x) #標準正規分布
plt.plot(x,y)

# %% [markdown]
# ## カーネル密度推定(KDE:Kernel Density Estimation)
#
# ・観測した分布から確率密度関数(確率分布)を推定する
# ![スクリーンショット 2024-06-30 21.24.41.png](attachment:1bb15015-2f03-4c28-84a0-d2e84a069736.png)

# %% [markdown]
# <u>KDEした確率分布を求める</u>
#
# ・stats.gaussian_kde(dataset)
#
# <u>KDEを描画する</u>
#
# ・sns.displot(a, kde=True)
#
# ・stats.gaussian_kde(dataset).pdf(x)

# %% [markdown]
# ## KDE

# %%
x = np.linspace(-3, 10, 100)
y = stats.gaussian_kde(df['tip']).pdf(x)
plt.plot(x,y)

# %%
y2 = stats.gaussian_kde(df['tip']).pdf(x)
plt.plot(x, y2)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_rate
# 0         16.99  1.01  Female     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4  0.146808
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.159744
#
# [244 rows x 8 columns]
